# %% [markdown]
# # Interpretable Machine Learning

# %% [markdown]
# ## Load Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

import eli5
from sklearn.inspection import plot_partial_dependence
import shap

# %% [markdown]
# ## Load Dataset

# %%
house_data = pd.read_csv("./dataset/house-prices-advanced-regression-techniques/train.csv")

# %%
cancer_data = pd.read_csv("./dataset/cancer/data.csv")

# %% [markdown]
# ## Data Inspections

# %%
house_data.isna().sum().sort_values()
# Out:
# Id                  0
# TotalBsmtSF         0
# Heating             0
# SaleCondition       0
# CentralAir          0
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# SaleType            0
# YrSold              0
# MoSold              0
# MiscVal             0
# PoolArea            0
# ScreenPorch         0
# BsmtUnfSF           0
# 3SsnPorch           0
# OpenPorchSF         0
# WoodDeckSF          0
# PavedDrive          0
# GarageArea          0
#                  ...
# YearBuilt           0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# ExterQual           0
# ExterCond           0
# Foundation          0
# MSSubClass          0
# YearRemodAdd        0
# Utilities           0
# Electrical          1
# MasVnrType          8
# MasVnrArea          8
# BsmtQual           37
# BsmtCond           37
# BsmtFinType1       37
# BsmtFinType2       38
# BsmtExposure       38
# GarageQual         81
# GarageFinish       81
# GarageYrBlt        81
# GarageType         81
# GarageCond         81
# LotFrontage       259
# FireplaceQu       690
# Fence            1179
# Alley            1369
# MiscFeature      1406
# PoolQC           1453
# Length: 81, dtype: int64

# %%
cancer_data.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# **Imputasi Data**

# %%
# imputasi data kategorik
cols_fillna = ['PoolQC','MiscFeature','Alley','Fence','MasVnrType','FireplaceQu',
               'GarageQual','GarageCond','GarageFinish','GarageType', 'Electrical',
               'KitchenQual', 'SaleType', 'Functional', 'Exterior2nd', 'Exterior1st',
               'BsmtExposure','BsmtCond','BsmtQual','BsmtFinType1','BsmtFinType2',
               'MSZoning', 'Utilities']

# Ganti nilai NA/NaN dengan 'NotAvail'
for col in cols_fillna:
    house_data[col].fillna('NotAvail',inplace=True)

# imputasi data numerik
house_data['LotFrontage'] = house_data['LotFrontage'].fillna(house_data['LotFrontage'].median(skipna=True))
house_data['GarageYrBlt'] = house_data['GarageYrBlt'].fillna(0)
house_data['MasVnrArea'] = house_data['MasVnrArea'].fillna(0)

# %%
house_data['MSSubClass'] = house_data['MSSubClass'].astype('object')

# %% [markdown]
# **One-Hot Encoding & Train-Test Split**

# %% [markdown]
# **Housing Data**

# %%
house_data = pd.get_dummies(house_data.iloc[:,1:])

# %%
house_data_y = house_data['SalePrice'].values
house_data_X = house_data.drop(columns='SalePrice').values
house_data_feature_names = house_data.drop(columns='SalePrice').columns.tolist()

# %% [markdown]
# **Cancer Data**

# %%
cancer_data_y = pd.get_dummies(cancer_data.iloc[:,1])['M'].values
cancer_data_X = cancer_data.iloc[:,2:].values
cancer_data_feature_names = cancer_data.iloc[:,2:].columns.tolist()

# %% [markdown]
# ## Model-Based Method

# %% [markdown]
# ### Linear Regression
#
# Pada pemodelan regresi linear, kita dapat menggunakan bobot yang diperoleh dari model untuk menerjemahkan dan mencari tahu prediktor mana yang paling penting atau berkontribusi positif/negatif terhadap naiknya/turunnya nilai dari target.
#
# Persamaan regresi:
#
# $$y = \beta_{0} + \beta_{1}x_{1} + \beta_{2}x_{2} + ... + \beta_{n}x_{n} + \epsilon$$
#
# Dimana:
#
# - $\beta_{0}, ..., \beta_{n}$ adalah bobot/koefisien yang diperoleh dari model
# - $\epsilon$ adalah nilai error

# %% [markdown]
# **Modeling**

# %%
model_regresi_linear = LinearRegression()
model_regresi_linear.fit(house_data_X, house_data_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# **Interpretasi**

# %%
eli5.explain_weights(model_regresi_linear, feature_names=house_data_feature_names)
# Out:
# Explanation(estimator='LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)', description="\nFeatures with largest coefficients.\nCaveats:\n1. Be careful with features which are not\n   independent - weights don't show their importance.\n2. If scale of input features is different then scale of coefficients\n   will also be different, making direct comparison between coefficient values\n   incorrect.\n3. Depending on regularization, rare features sometimes may have high\n   coefficients; this doesn't mean they contribute much to the\n   classification result for most examples.\n", error=None, method='linear model', is_regression=True, targets=[TargetExplanation(target='y', feature_weights=FeatureWeights(pos=[FeatureWeight(feature='PoolQC_NotAvail', weight=249410.06980837786, std=None, value=None), FeatureWeight(feature='RoofMatl_Membran', weight=144214.84490403446, std=None, value=None), FeatureWeight(feature='RoofMatl_Metal', weight=112066.45054446485, std=None, value=None), FeatureWeight(feature='GarageQual_Ex', weight=107799.30371912311, std=None, value=None), FeatureWeight(feature='RoofMatl_WdShngl', weight=102512.97700950601, std=None, value=None), FeatureWeight(feature='Condition2_PosA', weight=93254.49147978598, std=None, value=None), FeatureWeight(feature='RoofStyle_Shed', weight=77798.82886483181, std=None, value=None), FeatureWeight(feature='RoofMatl_Tar&Grv', weight=48337.46166314566, std=None, value=None), FeatureWeight(feature='RoofMatl_CompShg', weight=47396.85200785605, std=None, value=None), FeatureWeight(feature='Condition2_Artery', weight=46163.1570874449, std=None, value=None), FeatureWeight(feature='BsmtCond_Po', weight=45540.67978137173, std=None, value=None), FeatureWeight(feature='Condition2_RRNn', weight=43036.192675511105, std=None, value=None), FeatureWeight(feature='Neighborhood_StoneBr', weight=42342.01804121688, std=None, value=None)], neg=[FeatureWeight(feature='RoofMatl_ClyTile', weight=-535911.8217565082, std=None, value=None), FeatureWeight(feature='<BIAS>', weight=-219239.49002161316, std=None, value=None), FeatureWeight(feature='Condition2_PosN', weight=-194339.2381826669, std=None, value=None), FeatureWeight(feature='PoolQC_Fa', weight=-147391.3083437797, std=None, value=None), FeatureWeight(feature='PoolQC_Gd', weight=-118147.62576147694, std=None, value=None), FeatureWeight(feature='GarageCond_Ex', weight=-96548.6726945581, std=None, value=None), FeatureWeight(feature='Condition2_RRAe', weight=-88065.99995471955, std=None, value=None)], pos_remaining=163, neg_remaining=136), proba=None, score=None, weighted_spans=None, heatmap=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %% [markdown]
# ### Logistic Regression
#
# Sama halnya dengan model regresi linear, model logistic regression juga memiliki nilai bobot yang dapat diekstrak sehingga kita dapat mengetahui seberapa penting suatu variabel dibandingkan dengan variabel lainnya.
#
# Persamaan regresi logistik adalah:
#
# $$P(y=1) = \frac{1}{1+exp(-(\beta_{0} + \beta_{1}x_{1} + ... + \beta_{n}x_{n}))}$$
#
# Dimana:
#
# - P(y=1) adalah peluang terjadinya y=1
# - $\beta_{0}, ..., \beta_{n}$ adalah bobot/koefisien yang diperoleh dari model

# %% [markdown]
# **Modeling**

# %%
model_regresi_logistik = LogisticRegression(penalty='none', solver='sag')
model_regresi_logistik.fit(cancer_data_X, cancer_data_y)
# Out:
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:337: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='none',
#                    random_state=None, solver='sag', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
eli5.explain_weights(model_regresi_logistik, feature_names=cancer_data_feature_names, top=100)
# Out:
# Explanation(estimator="LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,\n                   intercept_scaling=1, l1_ratio=None, max_iter=100,\n                   multi_class='warn', n_jobs=None, penalty='none',\n                   random_state=None, solver='sag', tol=0.0001, verbose=0,\n                   warm_start=False)", description="\nFeatures with largest coefficients.\nCaveats:\n1. Be careful with features which are not\n   independent - weights don't show their importance.\n2. If scale of input features is different then scale of coefficients\n   will also be different, making direct comparison between coefficient values\n   incorrect.\n3. Depending on regularization, rare features sometimes may have high\n   coefficients; this doesn't mean they contribute much to the\n   classification result for most examples.\n", error=None, method='linear model', is_regression=False, targets=[TargetExplanation(target=1, feature_weights=FeatureWeights(pos=[FeatureWeight(feature='area_worst', weight=0.018703483088591617, std=None, value=None), FeatureWeight(feature='area_se', weight=0.009494920858220159, std=None, value=None), FeatureWeight(feature='concavity_worst', weight=0.00011648089131190907, std=None, value=None), FeatureWeight(feature='concavity_mean', weight=5.905432149629984e-05, std=None, value=None), FeatureWeight(feature='compactness_worst', weight=3.801570268660714e-05, std=None, value=None), FeatureWeight(feature='concave points_worst', weight=2.7399920671774312e-05, std=None, value=None), FeatureWeight(feature='concave points_mean', weight=2.6963370169867302e-05, std=None, value=None), FeatureWeight(feature='compactness_mean', weight=1.4006913803085365e-06, std=None, value=None), FeatureWeight(feature='concavity_se', weight=6.179296559057794e-07, std=None, value=None)], neg=[FeatureWeight(feature='perimeter_mean', weight=-0.02839261984470078, std=None, value=None), FeatureWeight(feature='perimeter_worst', weight=-0.028376680261476248, std=None, value=None), FeatureWeight(feature='area_mean', weight=-0.015280935649217262, std=None, value=None), FeatureWeight(feature='texture_worst', weight=-0.010515367832026203, std=None, value=None), FeatureWeight(feature='texture_mean', weight=-0.00832334392110889, std=None, value=None), FeatureWeight(feature='radius_worst', weight=-0.004912439932602689, std=None, value=None), FeatureWeight(feature='radius_mean', weight=-0.004787603483819408, std=None, value=None), FeatureWeight(feature='texture_se', weight=-0.0006495161889888102, std=None, value=None), FeatureWeight(feature='<BIAS>', weight=-0.0006470813952213209, std=None, value=None), FeatureWeight(feature='symmetry_worst', weight=-0.00013361615097306383, std=None, value=None), FeatureWeight(feature='perimeter_se', weight=-9.84237968229254e-05, std=None, value=None), FeatureWeight(feature='symmetry_mean', weight=-9.611862369460427e-05, std=None, value=None), FeatureWeight(feature='smoothness_worst', weight=-6.554185513446007e-05, std=None, value=None), FeatureWeight(feature='smoothness_mean', weight=-5.0335491713417696e-05, std=None, value=None), FeatureWeight(feature='radius_se', weight=-4.15978628769324e-05, std=None, value=None), FeatureWeight(feature='fractal_dimension_worst', weight=-3.9724184182060324e-05, std=None, value=None), FeatureWeight(feature='fractal_dimension_mean', weight=-3.9111327464677084e-05, std=None, value=None), FeatureWeight(feature='symmetry_se', weight=-1.0808066178872499e-05, std=None, value=None), FeatureWeight(feature='smoothness_se', weight=-4.069744332824196e-06, std=None, value=None), FeatureWeight(feature='fractal_dimension_se', weight=-1.4468129494198051e-06, std=None, value=None), FeatureWeight(feature='compactness_se', weight=-1.382073167478894e-06, std=None, value=None), FeatureWeight(feature='concave points_se', weight=-1.0863489516684097e-06, std=None, value=None)], pos_remaining=0, neg_remaining=0), proba=None, score=None, weighted_spans=None, heatmap=None)], feat ...

# %% [markdown]
# ### Decision Tree
#
# Model decision tree merupakan model yang sangat mudah diterjemahkan dikarenakan bentuknya yang berupa susunan dari keputusan-keputusan. Ada beberapa metode bagaimana kita dapat menerjemahkan/menginterpretasi model yang dibentuk oleh decision tree ini, diantaranya:
#
# - Feature Importance
# - Tree Decomposition

# %% [markdown]
# **Feature Importance**
#
# Feature Importance dihitung dengan cara sebagai berikut:
#
# $$\frac{N_{t}}{N} \times (impurity - \frac{N_{t_{right}}}{N_{t}} \times right_{impurity} - \frac{N_{t_{left}}}{N_{t}} \times left_{impurity})$$
#
# Dimana:
#
# - $N_{t}$: total sampel pada node tersebut.
# - $N$: total keseluruhan sampel
# - $N_{t_{right}}$: total sampel pada node di split kanan
# - $N_{t_{left}}$: total sampel pada node di split kiri
# - $impurity$: Nilai impuritas

# %%
model_decision_tree = DecisionTreeClassifier(random_state=1000, max_depth=3)
model_decision_tree.fit(cancer_data_X, cancer_data_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=1000, splitter='best')

# %%
eli5.sklearn.explain_decision_tree(model_decision_tree, feature_names=cancer_data_feature_names)
# Out:
# Explanation(estimator="DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,\n                       max_features=None, max_leaf_nodes=None,\n                       min_impurity_decrease=0.0, min_impurity_split=None,\n                       min_samples_leaf=1, min_samples_split=2,\n                       min_weight_fraction_leaf=0.0, presort=False,\n                       random_state=1000, splitter='best')", description='\nDecision tree feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='decision tree', is_regression=False, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='radius_worst', weight=0.7568813202167098, std=None, value=None), FeatureWeight(feature='concave points_worst', weight=0.1511799110538562, std=None, value=None), FeatureWeight(feature='texture_worst', weight=0.04198205961658928, std=None, value=None), FeatureWeight(feature='texture_mean', weight=0.03395718112407742, std=None, value=None), FeatureWeight(feature='smoothness_worst', weight=0.00803892766139344, std=None, value=None), FeatureWeight(feature='symmetry_worst', weight=0.007960600327373758, std=None, value=None), FeatureWeight(feature='compactness_se', weight=0.0, std=None, value=None), FeatureWeight(feature='perimeter_mean', weight=0.0, std=None, value=None), FeatureWeight(feature='area_mean', weight=0.0, std=None, value=None), FeatureWeight(feature='smoothness_mean', weight=0.0, std=None, value=None), FeatureWeight(feature='compactness_mean', weight=0.0, std=None, value=None), FeatureWeight(feature='concavity_mean', weight=0.0, std=None, value=None), FeatureWeight(feature='symmetry_mean', weight=0.0, std=None, value=None), FeatureWeight(feature='fractal_dimension_mean', weight=0.0, std=None, value=None), FeatureWeight(feature='radius_se', weight=0.0, std=None, value=None), FeatureWeight(feature='texture_se', weight=0.0, std=None, value=None), FeatureWeight(feature='perimeter_se', weight=0.0, std=None, value=None), FeatureWeight(feature='radius_mean', weight=0.0, std=None, value=None), FeatureWeight(feature='concave points_mean', weight=0.0, std=None, value=None), FeatureWeight(feature='fractal_dimension_worst', weight=0.0, std=None, value=None)], remaining=10), decision_tree=TreeInfo(criterion='gini', tree=NodeInfo(id=0, is_leaf=False, value=[357.0, 212.0], value_ratio=[0.6274165202108963, 0.37258347978910367], impurity=0.4675300607546925, samples=569, sample_ratio=1.0, feature_name='radius_worst', feature_id=20, threshold=16.795000076293945, left=NodeInfo(id=1, is_leaf=False, value=[346.0, 33.0], value_ratio=[0.9129287598944591, 0.0870712401055409], impurity=0.15897967850404826, samples=379, sample_ratio=0.6660808435852372, feature_name='concave points_worst', feature_id=27, threshold=0.13580000400543213, left=NodeInfo(id=2, is_leaf=False, value=[328.0, 5.0], value_ratio=[0.984984984984985, 0.015015015015015015], impurity=0.029579128678227762, samples=333, sample_ratio=0.5852372583479789, feature_name='symmetry_worst', feature_id=28, threshold=0.15654999762773514, left=NodeInfo(id=3, is_leaf=True, value=[0.0, 1.0], value_ratio=[0.0, 1.0], impurity=0.0, samples=1, sample_ratio=0.0017574692442882249, feature_name=None, feature_id=None, threshold=None, left=None, right=None), right=NodeInfo(id=4, is_leaf=True, value=[328.0, 4.0], value_ratio=[0.9879518072289156, 0.012048192771084338], impurity=0.023806067644070228, samples=332, sample_ratio=0.5834797891036907, feature_name=None, feature_id=None, threshold=None, left=None, right=None)), right=NodeInfo(id=5, is_leaf=False, value=[18.0, 28.0], value_ratio=[0.391304347826087, 0.6086956521739131], impurity=0.4763705103969754, samples=46, sample_ratio=0.08084358523725835, feature_name='texture_worst', feature_id=21, threshold=25.670000076293945, left=NodeInfo(id=6, is_leaf=True, value=[15.0, 4.0], value_ratio=[0.7894736842105263, 0.21052631578947367], impurity=0.332409972299169, samples=19, sample_ratio= ...

# %% [markdown]
# ## Model-Agnostic Methods
#
# Model-agnostic method dapat dianggap juga sebagai metode interpretasi model tanpa bergantung pada model itu sendiri.
#
# Beberapa keuntungan dari penggunaan metode ini diantaranya adalah:
#
# - *Model Flexibility*
# - *Explanation Flexibility*
# - *Representation Flexibility*

# %% [markdown]
# ### Partial Dependence Plot (PDP)
#
# Partial dependence plot (PDP) dapat digunakan untuk menunjukkan efek dari masing-masing variabel terhadap nilai prediksi. PDP dapat digunakan untuk menunjukkan apakah hubungan/kaitan antar variabel bersifat linear, monotonik, atau bentuk yang lebih kompleks.

# %%
for kolom in range(len(cancer_data_feature_names)):
    plot_partial_dependence(model_decision_tree, cancer_data_X, features=[kolom], feature_names=cancer_data_feature_names);
# Out:
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /home/qti/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /home/qti/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.3743307311889513, top=0.3743307311889513
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /home/qti/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37084718487306284, top=0.37084718487306284
#   ax.set_ylim(pdp_lim[1])
# /home/qti/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /home/qti/anaconda3/lib/python3.7/site-packages/sklearn/inspection/partial_dependence.py:658: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.37258347978910666, top=0.37258347978910666
#   ax.set_ylim(pdp_lim[1])

# %% [markdown]
# ### SHAP (SHapley Additive exPlanations) Feature Importance

# %% [markdown]
# SHAP adalah suatu metode yang digunakan untuk menjelaskan model berdasarkan nilai Shapley. Nilai Shapley diperoleh dengan cara menghitung nilai kontribusi yang diperoleh dari tiap variabel terhadap nilai prediksinya.

# %%
shap.initjs()
explainer = shap.TreeExplainer(model_decision_tree, cancer_data_X)
shap_values = explainer.shap_values(cancer_data_X, cancer_data_y)
shap.summary_plot(shap_values, cancer_data_X, feature_names=cancer_data_feature_names)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...
